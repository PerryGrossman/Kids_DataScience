# %% [markdown]
# # Hour of Code 2015
# For Mr. Clifford's Class (5C)
#
# Perry Grossman
#
# December 2015

# %% [markdown]
# ## Introduction
# From the Hour of Code to the Power of Co

# %% [markdown]
# How to use programming skills for data analysis, or "data science," the new, hot term

# %% [markdown]
# <img src="http://www.niemanlab.org/images/drew-conway-data-science-venn-diagram.jpg">

# %% [markdown]
# <img src="http://qph.is.quoracdn.net/main-qimg-3504cc03d0a1581096eba9ef97cfd7eb?convert_to_webp=true">

# %%
# you can also access this directly:
from PIL import Image
im = Image.open("DataScienceProcess.jpg")
im
#path=\'DataScienceProcess.jpg'
#image=Image.open(path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=582x601 at 0x7F49507CBA70>

# %% [markdown]
# # Some Basic Things

# %% [markdown]
# Leveraging a tutorial by David Beazley, Ian Stokes-Rees and Continuum Analytics
# http://localhost:8888/notebooks/Dropbox/Python/Harvard%20SEAS%20Tutorial/python-mastery-isr19-master/1-PythonReview.ipynb
#
# and other resources

# %%
# Comments
# ls list of the files in this folder. See below.
This line will make an error because this line is not python code and this is a code cell.
# Leveraging
#http://localhost:8888/notebooks/Dropbox/Python/Harvard%20SEAS%20Tutorial/python-mastery-isr19-master/1-PythonReview.ipynb
# Out:
#   File "<ipython-input-2-110c11bd529c>", line 3
#     This line will make an error because this line is not python code and this is a code cell.
#             ^
# SyntaxError: invalid syntax

# %%
ls # NOT PYTHON! command line
# Out:
# DataScienceProcess.jpg  HourofCode2015-Copy1.ipynb  Hour of Code 2015.pdf
# Data_Science_VD.png     HourofCode2015.ipynb

# %%
pwd # ALSO NOT PYTHON! Shows what folder you are in.
# Out:
# u'/home/perry/Dropbox/Python/Hour of Code 2015'

# %%
# math
1+2
# Out:
# 3

# %%
4000*3
# Out:
# 12000

# %%
import math
math.sqrt(2)
# Out:
# 1.4142135623730951

# %%
2 ** (0.5)
# Out:
# 1.4142135623730951

# %%
637*532.6
# Out:
# 339266.2

# %%
from __future__ import division
1/2
# Out:
# 0.5

# %%
(8+5)*4
# Out:
# 52

# %%
# Create a variable
name = 'Perry Grossman'

# %%
# Print the variable
name
# Out:
# 'Perry Grossman'

# %%
name[6]
# Out:
# 'G'

# %% [markdown]
# Floor numbering is the numbering scheme used for a building's floors. There are two major schemes in use across the world. In one system, used in the majority of Europe, the ground floor is the floor on the ground and often has no number or is assigned the number zero. Therefore, the next floor up is assigned the number 1 and is the first floor.
# The other system, used primarily in the United States and Canada, counts the bottom floor as number 1 or first floor.
#
# https://en.wikipedia.org/wiki/Storey

# %%
from functools import partial
# https://docs.python.org/2/library/functools.html
from random import choice, randint

# %%
choice('yes no maybe'.split()) # split is a method
# Out:
# 'maybe'

# %%
for i in range(10):
    print("Call me " + choice('yes no maybe'.split()))
# Out:
# Call me yes
# Call me maybe
# Call me yes
# Call me maybe
# Call me maybe
# Call me yes
# Call me maybe
# Call me maybe
# Call me no
# Call me maybe

# %%
randint(1, 6)
# Out:
# 3

# %%
# If you need dice, try this:

roll = partial(randint, 1, 20)

# %%
roll()
# how would you make 20 sided dice?
# Out:
# 6

# %%
# Create a list of numbers
vals = [3, -8, 2, 7, 6, 2, 5, 12, 4, 9]

# %%
#Find the even numbers
evens = []
for v in vals:
    if v%2 == 0:
        evens.append(v)
#How is this working?

# %%
evens
# Out:
# [-8, 2, 6, 2, 12, 4]

# %%
squares = []
for v in vals:
    squares.append(v*v)

# %%
squares
# Out:
# [9, 64, 4, 49, 36, 4, 25, 144, 16, 81]

# %%
bigsquares = []
for v in vals:
    s = v*v
    if s > 10:
        bigsquares.append(s)

# %%
bigsquares
# Out:
# [64, 49, 36, 25, 144, 16, 81]

# %% [markdown]
# See this for more data examples:
#
# http://localhost:8888/notebooks/Dropbox/Python/Harvard%20SEAS%20Tutorial/python-mastery-isr19-master/2-Data.ipynb

# %% [markdown]
# ##Now Let's use Python to Analyze Baby Names
#
# http://localhost:8888/notebooks/Dropbox/laptop-repos/Babynames2/Analysis_of_US_Baby_Names_1880-2008.ipynb

# %% [markdown]
# ##Now Let's use Python to Analyze Cars and Miles per Gallon
#
#
# http://localhost:8888/notebooks/Dropbox/Python/Dataminingtutorial/Python_For_Data_Mining-Copy1.ipynb

# %% [markdown]
# ##Now Let's use Python to Analyze US Energy Data
#
# https://github.com/PerryGrossman/DI5/blob/master/EnergyConsumptionEstimates_1949_2012-Residential_Sector.ipynb
#
#
# (http://localhost:8888/notebooks/repos/DI5/EnergyConsumptionEstimates_1949_2012-Residential_Sector.ipynb)

# %% [markdown]
# ##Now Let's use Python to Analyze Advertising Spend on Sales
#
# http://localhost:8888/notebooks/Dropbox/Python/Regression/08_linear_regression-Copy1.ipynb

# %% [markdown]
# ##Now Let's use Python to Look at Citizen Complaints in NYC
#
# http://localhost:8888/notebooks/Dropbox/Python/Test/PyDataNYC_2013_tutorial_pg.ipynb

# %% [markdown]
# ##Now Let's use Python to Look at Words in Emma, by Jane Austen
#
# http://localhost:8888/notebooks/Dropbox/Python/ThinkPython/Emma%20Text%20Analysis%20thinkpythonworkbook.ipynb

# %% [markdown]
# ---
# Am I a little obsessed with Python? Perhaps

# %% [markdown]
# <img src="https://lh3.googleusercontent.com/0nWepnl7_6c7R3QYv-IyW_IippYkAmSNq6vo-qkJXl86iDQXsg5L5yYmXYwMO4vhMUzLow=w1280-h720-rw-no">

# %% [markdown]
# ##Now Let's use Python to Analyze Nutrition Data
# (rough)
#
# http://localhost:8888/notebooks/Dropbox/Python/PandasTutorialFiles/NYCPython_FoodDB.ipynb

# %% [markdown]
# ##Now Let's use Python to Analyze US Presidential Election Data
# (very rough)
#
# http://localhost:8888/notebooks/Dropbox/Python/PandasTutorialFiles/FEC.v2-Copy_pg.ipynb

# %% [markdown]
# ##Now Let's use Python to Classify Olive Oils from their Fatty Acid Composition
#
# The percentage composition of fatty acids found in the lipid fraction of Italian olive oils', with oils from 3 regions of Italy: the North, the South, and Sardinia.
#
# Forina, M., Armanino, C., Lanteri, S. & Tiscornia, E. (1983), Classification of Olive Oils from their Fatty Acid Composition, in Martens, H. and Russwurm Jr., H., eds, Food Research and Data Analysis, Applied Science Publishers, London, pp. 189–214.
#
# http://localhost:8888/notebooks/Dropbox/laptop-repos/OliveOilMachineLearning/Olives_at_BDF-Copy0.ipynb

# %% [markdown]
# # Want to make some money?
# Start coding algorithms in python to predict the stock market
#
# https://www.quantopian.com/
#
# https://www.quantopian.com/lectures

# %% [markdown]
# # Resources

# %% [markdown]
# Local meetups, for kids:
# -
# http://www.meetup.com/CharlesRiver-CoderDojo/

# %% [markdown]
# Boston Python meetup, with pizza!:
# http://www.meetup.com/bostonpython/
#
# * It is run by Ned Batchelder (a former Lincoln parent)
# * http://nedbatchelder.com/

# %% [markdown]
# Online resources and books:
# http://localhost:8888/files/Dropbox/kids_programming_resources/Learn_to_Program_Resources_for_CharlesRiverCoderDojo.pdf

# %% [markdown]
# Anaconda integrates Python packages
#
# http://anaconda.org/
#
# Ian Stokes-Rees, parent of your former classmate, Maggie Stokes-Rees, works at Continuum Analytics, the company that makes anaconda and wakari, a web-based python solution.
#
# https://www.wakari.io
#
# Can be used from the web, from chromebooks

# %% [markdown]
# Python Weekly
#
#
# http://us2.campaign-archive1.com/home/?u=e2e180baf855ac797ef407fc7&id=9e26887fc5

# %% [markdown]
# Allen Downey
#
# http://allendowney.blogspot.com/

# %% [markdown]
# Stackoverflow
#
# http://stackoverflow.com/questions/20186100/upload-new-ipython-notebook-to-wakari
